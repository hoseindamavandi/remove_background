# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.cvtColor(cv2.imread('rouhani.jpg'), cv2.COLOR_RGB2HSV)
#plt.imshow(image)

# %%
bg = cv2.resize(cv2.imread('before.jpg'),(image.shape[1],image.shape[0]))
#plt.imshow(bg)

# %%
up = np.array([70, 255, 255])
low = np.array([50, 50, 50])

# %%
mask = cv2.inRange(image, low, up)
res = cv2.bitwise_and(image, image, mask=mask)
#plt.imshow(mask)

# %%
#plt.imshow(res)

# %%
result = image - res
result = cv2.cvtColor(result, cv2.COLOR_HSV2RGB)

result = np.where(result == 0, bg , result)
#plt.imshow(result)

# %%
result = cv2.cvtColor(result, cv2.COLOR_RGB2BGR)
plt.imshow(result)
